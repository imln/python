# %%
import numpy as np
import pandas as pd

# %%
#creating a DataFrame
df = pd.DataFrame(np.random.rand(10, 4), columns=('col_1', 'col_2', 'col_3', 'col_4'))

# %%
#displaying the DataFrame
df
# Out:
#       col_1     col_2     col_3     col_4
# 0  0.362444  0.225198  0.211879  0.738711
# 1  0.807262  0.213292  0.727803  0.474686
# 2  0.383774  0.097075  0.716638  0.103003
# 3  0.377763  0.499347  0.650782  0.759529
# 4  0.089630  0.686818  0.346153  0.419258
# 5  0.198950  0.258290  0.957287  0.838020
# 6  0.474340  0.754630  0.748851  0.324076
# 7  0.782015  0.581606  0.414096  0.382308
# 8  0.653406  0.690606  0.653142  0.334072
# 9  0.899143  0.804070  0.023065  0.527635

# %%
df.plot()

# %%
df.plot(x="col_1", y="col_2")

# %%
df.plot(subplots=True, figsize=(8, 8));

# %%
df.plot(kind='bar')

# %%
df.plot.bar(stacked=True)

# %%
df.plot.barh(stacked=True);

# %%
df.plot.hist()

# %%
df.plot.hist(stacked=True, bins=20);

# %%
df.plot.hist(orientation="horizontal", cumulative=True);

# %%
df.diff().hist();

# %%
df.plot.box()

# %%
df.boxplot()

# %%
df.plot.box(vert=False, positions=[1, 2, 3, 4]);

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %%
df.plot.scatter(x='col_1', y='col_3');

# %%
ax=df.plot.scatter(x="col_1", y="col_3", color="red", marker="*", s=100)

# %%
df.plot.scatter(x="col_2", y="col_4", color="orange", s=100, ax=ax)

# %%
df.plot.scatter(x="col_2", y="col_4", c='col_1', s=100)

# %%
pie = pd.Series(np.random.rand(5))
pie
# Out:
# 0    0.079719
# 1    0.134409
# 2    0.424853
# 3    0.339536
# 4    0.517082
# dtype: float64

# %%
pie.plot.pie();

# %%
#creating a DataFrame
df2 = pd.DataFrame(np.random.rand(6, 3), columns=('col_1', 'col_2', 'col_3'))
df2
# Out:
#       col_1     col_2     col_3
# 0  0.437516  0.531612  0.546829
# 1  0.896859  0.583213  0.296392
# 2  0.179648  0.924758  0.711961
# 3  0.923250  0.865553  0.748398
# 4  0.580663  0.995159  0.103642
# 5  0.028611  0.738659  0.437705

# %%
df2.plot.pie(subplots=True, figsize=(15, 15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f20d9a43d10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f20d9a3f2d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f20d9a4e550>],
#       dtype=object)
